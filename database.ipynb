-- %% [markdown]
-- # [DBTaskTracker]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DBTaskTracker]    Script Date: 12/12/2023 4:19:58 PM ******/
CREATE DATABASE [DBTaskTracker]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DBTaskTracker', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\DBTaskTracker.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DBTaskTracker_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\DBTaskTracker_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [DBTaskTracker] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DBTaskTracker].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DBTaskTracker] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DBTaskTracker] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DBTaskTracker] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DBTaskTracker] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DBTaskTracker] SET ARITHABORT OFF 
GO
ALTER DATABASE [DBTaskTracker] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [DBTaskTracker] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DBTaskTracker] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DBTaskTracker] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DBTaskTracker] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DBTaskTracker] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DBTaskTracker] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DBTaskTracker] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DBTaskTracker] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DBTaskTracker] SET  DISABLE_BROKER 
GO
ALTER DATABASE [DBTaskTracker] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DBTaskTracker] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DBTaskTracker] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DBTaskTracker] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DBTaskTracker] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DBTaskTracker] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DBTaskTracker] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DBTaskTracker] SET RECOVERY FULL 
GO
ALTER DATABASE [DBTaskTracker] SET  MULTI_USER 
GO
ALTER DATABASE [DBTaskTracker] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DBTaskTracker] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DBTaskTracker] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DBTaskTracker] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DBTaskTracker] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DBTaskTracker] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'DBTaskTracker', N'ON'
GO
ALTER DATABASE [DBTaskTracker] SET QUERY_STORE = ON
GO
ALTER DATABASE [DBTaskTracker] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[TB_Notes]

-- %%
USE [DBTaskTracker]
GO

-- %%
/****** Object:  Table [dbo].[TB_Notes]    Script Date: 12/12/2023 4:19:59 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TB_Notes](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Note_Desc] [nvarchar](max) NULL,
	[Note_Manager] [nvarchar](50) NULL,
	[Note_User] [nvarchar](50) NULL,
 CONSTRAINT [PK_TB_Notes] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TB_Projects]

-- %%
/****** Object:  Table [dbo].[TB_Projects]    Script Date: 12/12/2023 4:19:59 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TB_Projects](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[ProjectName] [nvarchar](50) NULL,
	[ProjectDes] [nvarchar](max) NULL,
 CONSTRAINT [PK_TB_Projects] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TB_Tasks]

-- %%
/****** Object:  Table [dbo].[TB_Tasks]    Script Date: 12/12/2023 4:19:59 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TB_Tasks](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[ID_Project] [int] NULL,
	[ID_User] [int] NULL,
	[Task_Name] [nvarchar](50) NULL,
	[Task_Desc] [nvarchar](max) NULL,
	[Task_User] [nvarchar](50) NULL,
	[Task_Admin] [nvarchar](50) NULL,
	[Task_Project] [nvarchar](50) NULL,
	[Task_Start] [date] NULL,
	[Task_End] [date] NULL,
	[Task_Duration] [int] NULL,
	[Task_State] [nvarchar](50) NULL,
 CONSTRAINT [PK_TB_Tasks] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TB_Users]

-- %%
/****** Object:  Table [dbo].[TB_Users]    Script Date: 12/12/2023 4:19:59 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TB_Users](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[FullName] [nvarchar](50) NULL,
	[UserName] [nvarchar](50) NULL,
	[Password] [nvarchar](50) NULL,
	[State] [nvarchar](50) NULL,
	[Role] [nvarchar](50) NULL,
	[image] [image] NULL,
 CONSTRAINT [PK_TB_Users] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_TB_Tasks_TB_Projects1]

-- %%
ALTER TABLE [dbo].[TB_Tasks]  WITH CHECK ADD  CONSTRAINT [FK_TB_Tasks_TB_Projects1] FOREIGN KEY([ID_Project])
REFERENCES [dbo].[TB_Projects] ([ID])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TB_Tasks] CHECK CONSTRAINT [FK_TB_Tasks_TB_Projects1]
GO

-- %% [markdown]
-- # [FK_TB_Tasks_TB_Users]

-- %%
ALTER TABLE [dbo].[TB_Tasks]  WITH CHECK ADD  CONSTRAINT [FK_TB_Tasks_TB_Users] FOREIGN KEY([ID_User])
REFERENCES [dbo].[TB_Users] ([ID])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TB_Tasks] CHECK CONSTRAINT [FK_TB_Tasks_TB_Users]
GO

-- %% [markdown]
-- # [DBTaskTracker]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DBTaskTracker] SET  READ_WRITE 
GO
